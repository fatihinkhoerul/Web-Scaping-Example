# %%
from bs4 import BeautifulSoup  # HTML data structure
import requests

# %%
page_url = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text

# %%
soup = BeautifulSoup(page_url, 'lxml')

# %%
jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')

# %%
# tanpa filter
for job in jobs:
    company_name = job.find('h3', class_='joblist-comp-name').text.replace('  ','')
    skills = job.find('span', class_='srp-skills').text.replace('  ','')
    published_date = job.find('span', class_='sim-posted').span.text
    
    print(f'''
Company Name : {company_name}
Required Skills : {skills}
Published Date : {published_date}
      ''')
    
    print('')
# Out:
# Company Name :
# ilabz technology ltd
#
#
# Required Skills :
# python,css,javascript,html,software developer
#
#
# Published Date : Posted 6 days ago
#
#
#
# Company Name :
# Surya Informatics Solutions Pvt. Ltd.
#
#
# Required Skills :
# python,web technologies,linux,mobile,mysql,angularjs,javascript
#
#
# Published Date : Posted few days ago
#
#
#
# Company Name :
# capgemini
#
#
# Required Skills :
#
# security compliance,python,html5,mobile,javascript,database,django,python scripting
#
#
# Published Date : Posted few days ago
#
#
#
# Company Name :
# Pure Tech Codex Private Limited
#
#
# Required Skills :
#
# rest,python,database,django,debugging,mongodb
#
#
# Published Date : Posted few days ago
#
#
#
# Company Name :
# Gemini Solutions
#
#
# Required Skills :
# python,mobile,svn,nosql,python scripting,git,api,sql database
#
#
# Published Date : Posted few days ago
#
#
#
# Company Name :
# GEMINI SOFTWARE SOLUTIONS
#
#
# Required Skills :
# python,mobile,svn,nosql,python scripting,git,sql database
#
#
# Published Date : Posted a month ago
#
#
#
# Company Name :
# RESEARCH DEVELOPERS
#  (More Jobs)
#
# Required Skills :
# python,research,python programmer,Machine Learning,Pattern Recognition,Image Processing,Digital Image,Signal Processing,Electronic Circuits,Network Analysis
#
#
# Published Date :
# Work from Home
#
#
#
#
# Company Name :
# Virtual Hr Solutions
#  (More Jobs)
#
# Required Skills :
# Python programmer
#
#
# Published Date : Posted 1 day ago
#
#
#
# Company Name :
# Willis Group Holdings
#
#
# Required Skills :
#
# c#,python,collaborative environment
#
#
# Published Date : Posted 1 day ago
#
#
#
# Company Name :
# 3RI Technologies Pvt Ltd
#
#
# Required Skills :
# python,database,team player
#
#
# Published Date : Posted 4 days ago
#
#
#
# Company Name :
# truetech solutions pvt ltd
#
#
# Required Skills :
# python,machine learning,api
#
#
# Published Date : Posted 5 days ago
#
#
#
# Company Name :
# Magic Finserv
#
#
# Required Skills :
# python,java,scala,infrastructure,javascript
#
#
# Published Date : Posted 1 day ago
#
#
#
# Company Name :
# LAKSH HUMAN RESOURCE
#
#
# Required Skills :
#
# rest,python,django,git
#
#
# Published Date : Posted few days ago
#
#
#
# Company Name :
# DREAMAJAX TECHNOLOGIES
#
#
# Required Skills :
# python,django,api,sql,nosql
#
#
# Published Date : Posted 5 days ago
#
#
#
# Company Name :
# SEVEN CONSULTANCY
#
#
# Required Skills :
# python,mvc,sql
#
#
# Published Date : Posted few days ago
#
#
#
# Company Name :
# FresherMart
#
#
# Required Skills :
# python,django, Django Framework
#
#
# Published Date : Posted few days ago
#
#
#
# Company Name :
# INITIATEFIRST INFORMATION SERVICES PRIVATE LIMITED
#
#
# Required Skills :
# python,sql,Data modeling
#
#
# Published Date : Posted few days ago
#
#
#
# Company Name :
# quality thought
#
#
# Required Skills :
#
# rest,python,django,information technology
#
#
# Published Date : Posted 6 days ago
#
#
#
# Company Name :
# Datagrid Solutions
#
#
# Required Skills :
# python,database,django,mysql,api
#
#
# Published Date : Posted 6 days ago
#
#
#
# Company Name :
# Gibots
#
#
# Required Skills :
# python, elements developed, performance applications
#
#
# Published Date : Posted few days ago
#
#
#
# Company Name :
# Anantha Cyber Tech Pvt Limited
#
#
# Required Skills :
# python,c,c,information technology
#
#
# Published Date : Posted few days ago
#
#
#
# Company Name :
# ValueLabs
#
#
# Required Skills :
# python,database,shell scripting,perl,unix,sql
#
#
# Published Date : Posted few days ago
#
#
#
# Company Name :
# Bosch Ltd
#
#
# Required Skills :
#
# docker,git,oops,api,rest,python
#
# Published Date : Posted 3 days ago
#
#
#
# Company Name :
# TECHNOPARK TRIVANDRUM
#
#
# Required Skills :
# python,devops,machine learning
#
#
# Published Date : Posted few days ago
#
#
#
# Company Name :
# TandA HR Solutions
#
#
# Required Skills :
#
# Django framework,Python Developer,core python
#
# Published Date : Posted few days ago

# %%
# dengan filter
for job in jobs:
    published_date = job.find('span', class_='sim-posted').span.text
    if 'few' in published_date:
        company_name = job.find('h3', class_='joblist-comp-name').text.replace('  ','')
        skills = job.find('span', class_='srp-skills').text.replace('  ','')
   
        print(f'''
        Company Name : {company_name}
        Required Skills : {skills}
        Published Date : {published_date}
          ''')
    
        print('')
# Out:
#         Company Name :
# Surya Informatics Solutions Pvt. Ltd.
#
#
#         Required Skills :
# python,web technologies,linux,mobile,mysql,angularjs,javascript
#
#
#         Published Date : Posted few days ago
#
#
#
#         Company Name :
# capgemini
#
#
#         Required Skills :
#
# security compliance,python,html5,mobile,javascript,database,django,python scripting
#
#
#         Published Date : Posted few days ago
#
#
#
#         Company Name :
# Pure Tech Codex Private Limited
#
#
#         Required Skills :
#
# rest,python,database,django,debugging,mongodb
#
#
#         Published Date : Posted few days ago
#
#
#
#         Company Name :
# Gemini Solutions
#
#
#         Required Skills :
# python,mobile,svn,nosql,python scripting,git,api,sql database
#
#
#         Published Date : Posted few days ago
#
#
#
#         Company Name :
# LAKSH HUMAN RESOURCE
#
#
#         Required Skills :
#
# rest,python,django,git
#
#
#         Published Date : Posted few days ago
#
#
#
#         Company Name :
# SEVEN CONSULTANCY
#
#
#         Required Skills :
# python,mvc,sql
#
#
#         Published Date : Posted few days ago
#
#
#
#         Company Name :
# FresherMart
#
#
#         Required Skills :
# python,django, Django Framework
#
#
#         Published Date : Posted few days ago
#
#
#
#         Company Name :
# INITIATEFIRST INFORMATION SERVICES PRIVATE LIMITED
#
#
#         Required Skills :
# python,sql,Data modeling
#
#
#         Published Date : Posted few days ago
#
#
#
#         Company Name :
# Gibots
#
#
#         Required Skills :
# python, elements developed, performance applications
#
#
#         Published Date : Posted few days ago
#
#
#
#         Company Name :
# Anantha Cyber Tech Pvt Limited
#
#
#         Required Skills :
# python,c,c,information technology
#
#
#         Published Date : Posted few days ago
#
#
#
#         Company Name :
# ValueLabs
#
#
#         Required Skills :
# python,database,shell scripting,perl,unix,sql
#
#
#         Published Date : Posted few days ago
#
#
#
#         Company Name :
# TECHNOPARK TRIVANDRUM
#
#
#         Required Skills :
# python,devops,machine learning
#
#
#         Published Date : Posted few days ago
#
#
#
#         Company Name :
# TandA HR Solutions
#
#
#         Required Skills :
#
# Django framework,Python Developer,core python
#
#         Published Date : Posted few days ago

# %%
# with strip()
for job in jobs:
    published_date = job.find('span', class_='sim-posted').span.text
    if 'few' in published_date:
        company_name = job.find('h3', class_='joblist-comp-name').text.replace('  ','')
        skills = job.find('span', class_='srp-skills').text.replace('  ','')
        more_info = job.header.h2.a['href']
   
        print(f'Company Name : {company_name.strip()}')
        print(f'Skills : {skills.strip()}')
        print(f'More Info : {more_info}')
        print('')
# Out:
# Company Name : Surya Informatics Solutions Pvt. Ltd.
# Skills : python,web technologies,linux,mobile,mysql,angularjs,javascript
# More Info : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name : capgemini
# Skills : security compliance,python,html5,mobile,javascript,database,django,python scripting
# More Info : https://www.timesjobs.com/job-detail/python-capgemini-pune-12-to-15-yrs-jobid-SnD3Qy3u93RzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name : Pure Tech Codex Private Limited
# Skills : rest,python,database,django,debugging,mongodb
# More Info : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name : Gemini Solutions
# Skills : python,mobile,svn,nosql,python scripting,git,api,sql database
# More Info : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name : LAKSH HUMAN RESOURCE
# Skills : rest,python,django,git
# More Info : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
#
# Company Name : SEVEN CONSULTANCY
# Skills : python,mvc,sql
# More Info : https://www.timesjobs.com/job-detail/python-developer-seven-consultancy-navi-mumbai-mumbai-4-to-7-yrs-jobid-PGeUDPey4RhzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name : FresherMart
# Skills : python,django, Django Framework
# More Info : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name : INITIATEFIRST INFORMATION SERVICES PRIVATE LIMITED
# Skills : python,sql,Data modeling
# More Info : https://www.timesjobs.com/job-detail/python-developer-initiatefirst-information-services-private-limited-hyderabad-secunderabad-5-to-8-yrs-jobid-Cd__SLASH__52aF2KCZzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name : Gibots
# Skills : python, elements developed, performance applications
# More Info : https://www.timesjobs.com/job-detail/python-developer-gibots-pune-1-to-2-yrs-jobid-3x1kaokioYFzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name : Anantha Cyber Tech Pvt Limited
# Skills : python,c,c,information technology
# More Info : https://www.timesjobs.com/job-detail/python-developer-anantha-cyber-tech-pvt-limited-hyderabad-secunderabad-3-to-6-yrs-jobid-QF9wZ4AGuzlzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name : ValueLabs
# Skills : python,database,shell scripting,perl,unix,sql
# More Info : https://www.timesjobs.com/job-detail/python-developer-valuelabs-hyderabad-secunderabad-7-to-10-yrs-jobid-ocUK970ERO9zpSvf__PLUS__uAgZw==&source=srp
#
# Company Name : TECHNOPARK TRIVANDRUM
# Skills : python,devops,machine learning
# More Info : https://www.timesjobs.com/job-detail/python-aws-technopark-trivandrum-thiruvananthapuram-4-to-6-yrs-jobid-DTeIKyAEWsNzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name : TandA HR Solutions
# Skills : Django framework,Python Developer,core python
# More Info : https://www.timesjobs.com/job-detail/python-developer-tanda-hr-solutions-mohali-3-to-5-yrs-jobid-GTT0grHZP1tzpSvf__PLUS__uAgZw==&source=srp

# %%
# with strip()
# filtering
print('Put some skills that you are not familiar with')
unfamiliar_skills = input('>>')
print(f'Filtering out :{unfamiliar_skills}')
for job in jobs:
    published_date = job.find('span', class_='sim-posted').span.text
    if 'few' in published_date:
        company_name = job.find('h3', class_='joblist-comp-name').text.replace('  ','')
        skills = job.find('span', class_='srp-skills').text.replace('  ','')
        more_info = job.header.h2.a['href']
        if unfamiliar_skills not in skills:
   
            print(f'Company Name : {company_name.strip()}')
            print(f'Skills : {skills.strip()}')
            print(f'More Info : {more_info}')
            print('')
# Out:
# Put some skills that you are not familiar with

# %%
# with strip()
# filtering
# save txt iterate
print('Put some skills that you are not familiar with')
unfamiliar_skills = input('>>')
print(f'Filtering out :{unfamiliar_skills}')
for index, job in enumerate(jobs):
    published_date = job.find('span', class_='sim-posted').span.text
    if 'few' in published_date:
        company_name = job.find('h3', class_='joblist-comp-name').text.replace('  ','')
        skills = job.find('span', class_='srp-skills').text.replace('  ','')
        more_info = job.header.h2.a['href']
        if unfamiliar_skills not in skills:
            with open(f'D:\Data Analyst\web scraping\{index}.xlsx','w') as f:
                
                f.write(f'Company Name : {company_name.strip()}\n')
                f.write(f'Skills : {skills.strip()}\n')
                f.write(f'More Info : {more_info}')
            print(f'File Saved : {index}')
